# %%
import geopandas as gps
import rasterio                  # I/O raster data (netcdf, height, geotiff, ...)
import rasterio.mask
import rasterio.warp             # Reproject raster samples
import rasterio.merge
from rasterio.transform import rowcol
from rasterio import features
import fiona                     # I/O vector data (shape, geojson, ...)
import pyproj                    # Change coordinate reference system
from osgeo import gdal,ogr,osr
import pandas as pd
import shapely
from shapely.geometry import box, Point
import json
import json
from sklearn.model_selection import train_test_split
import shutil
import numpy as np               # numerical array manipulation
import time
import os
from PIL import Image
import PIL.ImageDraw
from core.visualize import display_images

import matplotlib.pyplot as plt  # plotting tools
# %matplotlib inline
from tqdm import tqdm_notebook as tqdm
from tqdm import trange
import warnings                  # ignore annoying warnings
warnings.filterwarnings("ignore")

# %reload_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from multiprocessing import Pool

# %%
# Required configurations (including the input and output paths) are stored in a separate file (such as config/Preprocessing.py)
# Please provide required info in the file before continuing with this notebook. 
# hbh: in this scene,a new config named Preprocessing_within is created to distinguish from the original
from config import Preprocessing   
# In case you are using a different folder name such as configLargeCluster, then you should import from the respective folder 
# Eg. from configLargeCluster import Preprocessing
config = Preprocessing.Configuration()

# %%
base_dir = r'D:\lakemapping'
output_dir=r'D:\sample'
raw_img_dir=os.path.join(base_dir , r'sample750_pad\tif')
training_area_fn =os.path.join(base_dir , r'2_dataset\sampleAnnotations\SampleV9\raw_total_area.shp')
training_polygon_fn = os.path.join(base_dir ,r'2_dataset\sampleAnnotations\SampleV9\raw_total_polygon.shp')


raw_area_prefix='raw_area_'
area_prefix='area_'
pad_area_prefix='pad_area_'
raw_image_prefix='sample_'
image_prefix='image_'
pad_image_prefix='pad_image_'
annotation_prefix='annotation_'
area_file_type='.shp'
image_file_type='.tif'
annotation_file_type='.png'
type_num=5

model_dir = os.path.join(base_dir,r'3_training\U_Net')
dataset_dir=os.path.join(base_dir ,'2_dataset')  
patch_size = (576,576,6) 
patch_dir = os.path.join(model_dir,'patches{}'.format(patch_size[0])) 
# The training areas are divided into training, validation and testing set. Note that training area can have different sizes, so it doesn't guarantee that the final generated patches (when using sequential stratergy) will be in the same ratio.
test_ratio = 0.2
val_ratio = 0.25

# %% [markdown]
# ## 提取shapefile
# 将shapefile按类别存储为单个文件，以便后续裁剪

# %%
for i in range(0,type_num):
    writePath=os.path.join(output_dir,r'image\output{}'.format(i))
    if not os.path.exists(writePath):
        os.makedirs(writePath)
    writePath=os.path.join(output_dir,r'raw_image\output{}'.format(i))
    if not os.path.exists(writePath):
        os.makedirs(writePath)
    writePath2=os.path.join(output_dir,r'shp\output{}'.format(i))
    if not os.path.exists(writePath2):
        os.makedirs(writePath2)

# %%
trainingArea = gps.read_file(training_area_fn)
for i in tqdm(trainingArea.index):
    fn=trainingArea.loc[i]['file_name']
    ty=trainingArea.loc[i]['type']
    writePath=os.path.join(output_dir,r'shp\output{}'.format(ty))
    shape=trainingArea[i:i+1]
    fn=os.path.join(writePath,raw_area_prefix+fn+area_file_type)
    if not os.path.exists(fn):
        print(fn)
        shape.to_file()
# Out:
#   0%|          | 0/747 [00:00<?, ?it/s]

# %% [markdown]
# ## 裁剪sampe影像，获得image影像

# %%
def Image_Compress(path_image, path_out_image):
    """
    :param path_image: 输入需要压缩的影像路径
    :param path_out_image: 输出压缩后的影像路径
    :return: None
    """
    ds = gdal.Open(path_image)
    # 打开影像数据
    driver = gdal.GetDriverByName('GTiff')
    # 创建输出的数据驱动
    driver.CreateCopy(path_out_image, ds, strict=1, 
                      options=["TILED=YES", "COMPRESS=LZW", "BIGTIFF=YES"])
    # 设置压缩参数
    """
    PACKBITS：连续字节压缩，快速无损压缩
    LZW：所有信息全部保留（可逆），以某一数值代替字符串，快速无损压缩
    """
    del ds


for i in range(0,type_num):
    all_files = []
    for root, dirs, files in os.walk(os.path.join(output_dir,'shp\output{}'.format(i))):
        for file in files:
            if file.endswith(area_file_type)and file.startswith(raw_area_prefix):
                 all_files.append((os.path.join(root, file), file))
                    
    for in_shp_path, filename in all_files:
        print(in_shp_path)
        raster_fn=os.path.join(raw_img_dir,filename.replace(raw_area_prefix,raw_image_prefix).replace(area_file_type,image_file_type))
        input_raster = gdal.Open(raster_fn)
        out_raw_raster_path=in_shp_path.replace(raw_area_prefix,image_prefix).replace(area_file_type,image_file_type).replace('shp','raw_image')
        out_raster_path=out_raw_raster_path.replace('raw_','')
        if not os.path.exists(out_raw_raster_path):
            print(raster_fn)
            print(out_raw_raster_path)
                # 利用gdal.Warp进行裁剪
                # https://gdal.org/api/python/osgeo.gdal.html#osgeo.gdal.Warp
            result = gdal.Warp(
                    out_raw_raster_path,
                    input_raster,
                    format = 'GTiff',
                    cutlineDSName = in_shp_path, # 用于裁剪的矢量
                    cropToCutline = True, # 是否使用cutlineDSName的extent作为输出的界线
    #                 dstNodata = -999 # 输出数据的nodata值
                    )
            result.FlushCache()
            del result
        if not os.path.exists(out_raster_path):
            print(out_raster_path)
            Image_Compress(out_raw_raster_path,out_raster_path)
            print('compressed')
# Out:
# D:\sample\shp\output0\raw_area_10031.shp
# D:\sample\shp\output0\raw_area_10150.shp
# D:\sample\shp\output0\raw_area_10174.shp
# D:\sample\shp\output0\raw_area_10332.shp
# D:\sample\shp\output0\raw_area_10358.shp
# D:\sample\shp\output0\raw_area_10383.shp
# D:\sample\shp\output0\raw_area_10408.shp
# D:\sample\shp\output0\raw_area_10689.shp
# D:\sample\shp\output0\raw_area_10713.shp
# D:\sample\shp\output0\raw_area_10856.shp
# D:\sample\shp\output0\raw_area_10892.shp
# D:\sample\shp\output0\raw_area_10928.shp
# D:\sample\shp\output0\raw_area_11020_3.shp
# D:\sample\shp\output0\raw_area_11081.shp
# D:\sample\shp\output0\raw_area_11289.shp
# D:\sample\shp\output0\raw_area_11306.shp
# D:\sample\shp\output0\raw_area_11324.shp
# D:\sample\shp\output0\raw_area_11383.shp
# D:\sample\shp\output0\raw_area_11428.shp
# D:\sample\shp\output0\raw_area_11490.shp
# D:\sample\shp\output0\raw_area_11601.shp
# D:\sample\shp\output0\raw_area_11664.shp
# D:\sample\shp\output0\raw_area_11740.shp
# D:\sample\shp\output0\raw_area_11773.shp
# D:\sample\shp\output0\raw_area_11904.shp
# D:\sample\shp\output0\raw_area_15612.shp
# D:\sample\shp\output0\raw_area_1565.shp
# D:\sample\shp\output0\raw_area_15693.shp
# D:\sample\shp\output0\raw_area_15816.shp
# D:\sample\shp\output0\raw_area_15898.shp
# D:\sample\shp\output0\raw_area_16071.shp
# D:\sample\shp\output0\raw_area_16178.shp
# D:\sample\shp\output0\raw_area_1621.shp
# D:\sample\shp\output0\raw_area_16227.shp
# D:\sample\shp\output0\raw_area_1625.shp
# D:\sample\shp\output0\raw_area_16329.shp
# D:\sample\shp\output0\raw_area_16333.shp
# D:\sample\shp\output0\raw_area_16388.shp
# D:\sample\shp\output0\raw_area_16458.shp
# D:\sample\shp\output0\raw_area_16483.shp
# D:\sample\shp\output0\raw_area_1652.shp
# D:\sample\shp\output0\raw_area_16526.shp
# D:\sample\shp\output0\raw_area_16599.shp
# D:\sample\shp\output0\raw_area_16653.shp
# D:\sample\shp\output0\raw_area_1673.shp
# D:\sample\shp\output0\raw_area_168.shp
# D:\sample\shp\output0\raw_area_16816.shp
# D:\sample\shp\output0\raw_area_16901.shp
# D:\sample\shp\output0\raw_area_1704.shp
# D:\sample\shp\output0\raw_area_1712.shp
# D:\sample\shp\output0\raw_area_17161.shp
# D:\sample\shp\output0\raw_area_17175.shp
# D:\sample\shp\output0\raw_area_1727.shp
# D:\sample\shp\output0\raw_area_17517.shp
# D:\sample\shp\output0\raw_area_17553.shp
# D:\sample\shp\output0\raw_area_178.shp
# D:\sample\shp\output0\raw_area_17955.shp
# D:\sample\shp\output0\raw_area_18071.shp
# D:\sample\shp\output0\raw_area_18153.shp
# D:\sample\shp\output0\raw_area_18200.shp
# D:\sample\shp\output0\raw_area_18247.shp
# D:\sample\shp\output0\raw_area_18272.shp
# D:\sample\shp\output0\raw_area_18304.shp
# D:\sample\shp\output0\raw_area_18337.shp
# D:\sample\shp\output0\raw_area_18375.shp
# D:\sample\shp\output0\raw_area_18397.shp
# D:\sample\shp\output0\raw_area_18447.shp
# D:\sample\shp\output0\raw_area_18575.shp
# D:\sample\shp\output0\raw_area_18682.shp
# D:\sample\shp\output0\raw_area_18782.shp
# D:\sample\shp\output0\raw_area_18890.shp
# D:\sample\shp\output0\raw_area_18899.shp
# D:\sample\shp\output0\raw_area_1903.shp
# D:\sample\shp\output0\raw_area_1941.shp
# D:\sample\shp\output0\raw_area_1963.shp
# D:\sample\shp\output0\raw_area_1972.shp
# D:\sample\shp\output0\raw_area_2051.shp
# D:\sample\shp\output0\raw_area_2320.shp
# D:\sample\shp\output0\raw_area_2345.shp
# D:\sample\shp\output0\raw_area_2433.shp
# D:\sample\shp\output0\raw_area_2589.shp
# D:\sample\shp\output0\raw_area_2720.shp
# D:\sample\shp\output0\raw_area_2893.shp
# D:\sample\shp\output0\raw_area_2923.shp
# D:\sample\shp\output0\raw_area_3015.shp
# D:\sample\shp\output0\raw_area_3058.shp
# D:\sample\shp\output0\raw_area_3250.shp
# D:\sample\shp\output0\raw_area_3272.shp
# D:\sample\shp\output0\raw_area_343.shp
# D:\sample\shp\output0\raw_area_3444.shp
# D:\sample\shp\output2\raw_area_3023.shp
# D:\sample\shp\output2\raw_area_3205.shp
# D:\sample\shp\output2\raw_area_3421.shp
# D:\sample\shp\output2\raw_area_3454.shp
# D:\sample\shp\output2\raw_area_3461.shp
# D:\sample\shp\output2\raw_area_347.shp
# D:\sample\shp\output2\raw_area_3477.shp
# D:\sample\shp\output2\raw_area_349.shp
# D:\sample\shp\output2\raw_area_3501.shp
# D:\sample\shp\output2\raw_area_3535.shp
# D:\sample\shp\output2\raw_area_3565.shp
# D:\sample\shp\output2\raw_area_3624.shp
# D:\sample\shp\output2\raw_area_3876.shp
# D:\sample\shp\output2\raw_area_3886.shp
# D:\sample\shp\output2\raw_area_3921.shp
# D:\sample\shp\output2\raw_area_3928.shp
# D:\sample\shp\output2\raw_area_3932.shp
# D:\sample\shp\output2\raw_area_4030.shp
# D:\sample\shp\output2\raw_area_4052.shp
# D:\sample\shp\output2\raw_area_4482.shp
# D:\sample\shp\output2\raw_area_4582.shp
# D:\sample\shp\output2\raw_area_4631.shp
# D:\sample\shp\output2\raw_area_4850.shp
# D:\sample\shp\output2\raw_area_4851.shp
# D:\sample\shp\output2\raw_area_4886.shp
# D:\sample\shp\output2\raw_area_4892.shp
# D:\sample\shp\output2\raw_area_4917.shp
# D:\sample\shp\output2\raw_area_4949.shp
# D:\sample\shp\output2\raw_area_4976.shp
# D:\sample\shp\output2\raw_area_5039.shp
# D:\sample\shp\output2\raw_area_5053.shp
# D:\sample\shp\output2\raw_area_5062.shp
# D:\sample\shp\output2\raw_area_5087.shp
# D:\sample\shp\output2\raw_area_5116_1.shp
# D:\sample\shp\output2\raw_area_5116_2.shp
# D:\sample\shp\output2\raw_area_5123.shp
# D:\sample\shp\output2\raw_area_5264.shp
# D:\sample\shp\output2\raw_area_5560.shp
# D:\sample\shp\output2\raw_area_5719.shp
# D:\sample\shp\output2\raw_area_5919.shp
# D:\sample\shp\output2\raw_area_6182.shp
# D:\sample\shp\output2\raw_area_6193.shp
# D:\sample\shp\output2\raw_area_6198.shp
# D:\sample\shp\output2\raw_area_6217.shp
# D:\sample\shp\output2\raw_area_6226.shp
# D:\sample\shp\output2\raw_area_6233.shp
# D:\sample\shp\output2\raw_area_6339.shp
# D:\sample\shp\output2\raw_area_6377.shp
# D:\sample\shp\output2\raw_area_6402.shp
# D:\sample\shp\output2\raw_area_6445_1.shp
# D:\sample\shp\output2\raw_area_6445_2.shp
# D:\sample\shp\output2\raw_area_6448.shp
# D:\sample\shp\output2\raw_area_6741.shp
# D:\sample\shp\output2\raw_area_7032.shp
# D:\sample\shp\output2\raw_area_7084.shp
# D:\sample\shp\output2\raw_area_7117.shp
# D:\sample\shp\output2\raw_area_7156.shp
# D:\sample\shp\output2\raw_area_7192.shp
# D:\sample\shp\output2\raw_area_7196.shp
# D:\sample\shp\output2\raw_area_7249.shp
# D:\sample\shp\output2\raw_area_7255.shp
# D:\sample\shp\output2\raw_area_7366.shp
# D:\sample\shp\output2\raw_area_7453.shp
# D:\sample\shp\output2\raw_area_7564.shp
# D:\sample\shp\output5\raw_area_3194.shp
# D:\sample\shp\output5\raw_area_3202.shp
# D:\sample\shp\output5\raw_area_4299.shp
# D:\sample\shp\output5\raw_area_4418.shp
# D:\sample\shp\output5\raw_area_5605.shp
# D:\sample\shp\output5\raw_area_5636.shp
# D:\sample\shp\output5\raw_area_6252.shp
# D:\sample\shp\output5\raw_area_6765.shp
# D:\sample\shp\output5\raw_area_6779.shp
# D:\sample\shp\output5\raw_area_6794.shp
# D:\sample\shp\output5\raw_area_8456.shp
# D:\sample\shp\output5\raw_area_8555.shp
# D:\sample\shp\output5\raw_area_8904.shp

# %% [markdown]
# ## 提取shapefile
# 读取image影像，保存影像边界，pad width 为92个像素

# %%
for i in range(0,type_num):
    writePath=os.path.join(output_dir,r'image\output{}'.format(i))
    shpWritePath=os.path.join(output_dir,r'shp\output{}'.format(i))
    
    all_files = []
    for root, dirs, files in os.walk(writePath):
        for file in files:
            if file.endswith(image_file_type)and file.startswith(image_prefix):
                 all_files.append((os.path.join(root, file), file))
    # print(all_files)

    for fullPath, filename in all_files:
        print(filename)
        shp_fn=filename.replace(image_file_type,area_file_type).replace(image_prefix,pad_area_prefix).replace('image','shp')
#         print(shp_fn)
        dataset = gdal.Open(fullPath)
        geocd=dataset.GetGeoTransform()
        outfilename =os.path.join(shpWritePath,shp_fn)
        if not os.path.exists(outfilename):
            print(outfilename)
            oDriver = ogr.GetDriverByName('ESRI Shapefile')
            oDS = oDriver.CreateDataSource(outfilename)
            srs = osr.SpatialReference(wkt=dataset.GetProjection())
            oLayer = oDS.CreateLayer("polygon", srs, ogr.wkbPolygon)
            oDefn = oLayer.GetLayerDefn()
            row = dataset.RasterXSize+92
            line = dataset.RasterYSize+92
            geoxmin = geocd[0]-92*geocd[1]-92*geocd[2]
            geoymin = geocd[3]-92*geocd[4]-92*geocd[5]
            geoxmax = geocd[0] + (row) * geocd[1] + (line) * geocd[2]
            geoymax = geocd[3] + (row) * geocd[4] + (line) * geocd[5]
            ring = ogr.Geometry(ogr.wkbLinearRing)
            ring.AddPoint(geoxmin, geoymin)
            ring.AddPoint(geoxmax, geoymin)
            ring.AddPoint(geoxmax, geoymax)
            ring.AddPoint(geoxmin, geoymax)
            ring.CloseRings()
            poly = ogr.Geometry(ogr.wkbPolygon)
            poly.AddGeometry(ring)
            outfeat = ogr.Feature(oDefn)
            outfeat.SetGeometry(poly)
            oLayer.CreateFeature(outfeat)
            outfeat = None
# Out:
# image_10031.tif
# image_10150.tif
# image_10174.tif
# image_10332.tif
# image_10358.tif
# image_10383.tif
# image_10408.tif
# image_10689.tif
# image_10713.tif
# image_10856.tif
# image_10892.tif
# image_10928.tif
# image_11020_3.tif
# image_11081.tif
# image_11289.tif
# image_11306.tif
# image_11324.tif
# image_11383.tif
# image_11428.tif
# image_11490.tif
# image_11601.tif
# image_11664.tif
# image_11740.tif
# image_11773.tif
# image_11904.tif
# image_12000.tif
# image_12234.tif
# image_12262.tif
# image_12277.tif
# image_12312.tif
# image_12344.tif
# image_12351.tif
# image_12389.tif
# image_12395.tif
# image_16118.tif
# image_17140.tif
# image_17434.tif
# image_17481.tif
# image_17683.tif
# image_17753.tif
# image_17883.tif
# image_18710.tif
# image_18725.tif
# image_2883.tif
# image_2979.tif
# image_2986.tif
# image_3126.tif
# image_3159.tif
# image_3194.tif
# image_3202.tif
# image_4299.tif
# image_4418.tif
# image_5605.tif
# image_5636.tif
# image_6252.tif
# image_6765.tif
# image_6779.tif
# image_6794.tif
# image_8456.tif
# image_8555.tif
# image_8904.tif

# %%
# all_files = []
# shpWritePath=r'D:\lakemapping\2_dataset\shp\val_2'
# for root, dirs, files in os.walk(r'D:\lakemapping\2_dataset\patchesReshape\val'):
#     for file in files:
#         if file.endswith(image_file_type)and file.startswith(image_prefix):
#              all_files.append((os.path.join(root, file), file))
# print(all_files)
for i in range(0,type_num):
    writePath=os.path.join(output_dir,r'image\output{}'.format(i))
    shpWritePath=os.path.join(output_dir,r'shp\output{}'.format(i))
    
    all_files = []
    for root, dirs, files in os.walk(writePath):
        for file in files:
            if file.endswith(image_file_type)and file.startswith(image_prefix):
                 all_files.append((os.path.join(root, file), file))
    # print(all_files)

    for fullPath, filename in all_files:
        print(filename)
        shp_fn=filename.replace(image_file_type,area_file_type).replace(image_prefix,area_prefix).replace('image','shp')
#         print(shp_fn)
        dataset = gdal.Open(fullPath)
        geocd=dataset.GetGeoTransform()
        outfilename =os.path.join(shpWritePath,shp_fn)
        if not os.path.exists(outfilename):
            print(outfilename)
            oDriver = ogr.GetDriverByName('ESRI Shapefile')
            oDS = oDriver.CreateDataSource(outfilename)
            srs = osr.SpatialReference(wkt=dataset.GetProjection())
            oLayer = oDS.CreateLayer("polygon", srs, ogr.wkbPolygon)
            oDefn = oLayer.GetLayerDefn()
            row = dataset.RasterXSize
            line = dataset.RasterYSize
            geoxmin = geocd[0]
            geoymin = geocd[3]
            geoxmax = geocd[0] + (row) * geocd[1] + (line) * geocd[2]
            geoymax = geocd[3] + (row) * geocd[4] + (line) * geocd[5]
            ring = ogr.Geometry(ogr.wkbLinearRing)
            ring.AddPoint(geoxmin, geoymin)
            ring.AddPoint(geoxmax, geoymin)
            ring.AddPoint(geoxmax, geoymax)
            ring.AddPoint(geoxmin, geoymax)
            ring.CloseRings()
            poly = ogr.Geometry(ogr.wkbPolygon)
            poly.AddGeometry(ring)
            outfeat = ogr.Feature(oDefn)
            outfeat.SetGeometry(poly)
            oLayer.CreateFeature(outfeat)
            outfeat = None
# Out:
# image_10031.tif
# image_10150.tif
# image_10174.tif
# image_10332.tif
# image_10358.tif
# image_10383.tif
# image_10408.tif
# image_10689.tif
# image_10713.tif
# image_10856.tif
# image_10892.tif
# image_10928.tif
# image_11020_3.tif
# image_11081.tif
# image_11289.tif
# image_11306.tif
# image_11324.tif
# image_11383.tif
# image_11428.tif
# image_11490.tif
# image_11601.tif
# image_11664.tif
# image_11740.tif
# image_11773.tif
# image_11904.tif
# image_12000.tif
# image_12234.tif
# image_12262.tif
# image_12277.tif
# image_12312.tif
# image_12344.tif
# image_12351.tif
# image_12389.tif
# image_12395.tif
# image_12443.tif
# image_17434.tif
# image_17481.tif
# image_17683.tif
# image_17753.tif
# image_17883.tif
# image_18710.tif
# image_18725.tif
# image_2883.tif
# image_2979.tif
# image_2986.tif
# image_3126.tif
# image_3159.tif
# image_3194.tif
# image_3202.tif
# image_4299.tif
# image_4418.tif
# image_5605.tif
# image_5636.tif
# image_6252.tif
# image_6765.tif
# image_6779.tif
# image_6794.tif
# image_8456.tif
# image_8555.tif
# image_8904.tif

# %% [markdown]
# ## 裁剪sampe影像，获得pad image影像

# %%
for i in range(0,type_num):
    all_files = []
    for root, dirs, files in os.walk(os.path.join(output_dir,'shp\output{}'.format(i))):
        for file in files:
            if file.endswith(area_file_type)and file.startswith(pad_area_prefix):
                 all_files.append((os.path.join(root, file), file))
#     print(all_files)                    
    for fullPath, filename in all_files:
        print(filename)
        out_raw_raster_path=fullPath.replace(pad_area_prefix,pad_image_prefix).replace(area_file_type,image_file_type).replace('shp','raw_image')
        out_raster_path=out_raw_raster_path.replace('raw_','')
        
        if not os.path.exists(out_raw_raster_path):
            raster_fn=os.path.join(raw_img_dir,filename.replace(pad_area_prefix,raw_image_prefix).replace(area_file_type,image_file_type))#.replace('_1','').replace('_2','')
            print(raster_fn)
            input_raster = gdal.Open(raster_fn)
            in_shp_path=fullPath
            print(out_raw_raster_path)
                # 利用gdal.Warp进行裁剪
                # https://gdal.org/api/python/osgeo.gdal.html#osgeo.gdal.Warp
            result = gdal.Warp(
                    out_raw_raster_path,
                    input_raster,
                    format = 'GTiff',
                    cutlineDSName = in_shp_path, # 用于裁剪的矢量
                    cropToCutline = True, # 是否使用cutlineDSName的extent作为输出的界线
    #                 dstNodata = -999 # 输出数据的nodata值
                    )
            result.FlushCache()
            del result
        if not os.path.exists(out_raster_path):
            Image_Compress(out_raw_raster_path,out_raster_path)
            print('compressed')
# Out:
# pad_area_10031.shp
# pad_area_10150.shp
# pad_area_10174.shp
# pad_area_10332.shp
# pad_area_10358.shp
# pad_area_10383.shp
# pad_area_10408.shp
# pad_area_10689.shp
# pad_area_10713.shp
# pad_area_10856.shp
# pad_area_10892.shp
# pad_area_10928.shp
# pad_area_11020_3.shp
# pad_area_11081.shp
# pad_area_11289.shp
# pad_area_11306.shp
# pad_area_11324.shp
# pad_area_11383.shp
# pad_area_11428.shp
# pad_area_11490.shp
# pad_area_11601.shp
# pad_area_11664.shp
# pad_area_11740.shp
# pad_area_11773.shp
# pad_area_11904.shp
# pad_area_12000.shp
# pad_area_12234.shp
# pad_area_12262.shp
# pad_area_12277.shp
# pad_area_12312.shp
# pad_area_12344.shp
# pad_area_12351.shp
# pad_area_12389.shp
# pad_area_12395.shp
# pad_area_12443.shp
# pad_area_12455.shp
# pad_area_12596.shp
# pad_area_1260.shp
# pad_area_12602.shp
# pad_area_12637.shp
# pad_area_12666.shp
# pad_area_12688.shp
# pad_area_12821.shp
# pad_area_12843.shp
# pad_area_13177.shp
# pad_area_13224.shp
# pad_area_13246.shp
# pad_area_13251.shp
# pad_area_13307.shp
# pad_area_13362.shp
# pad_area_13407.shp
# pad_area_13411_2.shp
# pad_area_13554.shp
# pad_area_13582.shp
# pad_area_13618.shp
# pad_area_13705.shp
# pad_area_13742.shp
# pad_area_13748.shp
# pad_area_13830.shp
# pad_area_13928.shp
# pad_area_13944.shp
# pad_area_13962.shp
# pad_area_13979.shp
# pad_area_14006.shp
# pad_area_14077.shp
# pad_area_14084.shp
# pad_area_14111.shp
# pad_area_14206.shp
# pad_area_14422.shp
# pad_area_14449.shp
# pad_area_14494.shp
# pad_area_14689.shp
# pad_area_147.shp
# pad_area_14735.shp
# pad_area_14753.shp
# pad_area_14781.shp
# pad_area_14807.shp
# pad_area_14836.shp
# pad_area_14857.shp
# pad_area_14862.shp
# pad_area_14872.shp
# pad_area_14914.shp
# pad_area_14926.shp
# pad_area_14947.shp
# pad_area_14975.shp
# pad_area_14997.shp
# pad_area_15009.shp
# pad_area_1543_1.shp
# pad_area_1543_2.shp
# pad_area_15612.shp
# pad_area_1565.shp
# pad_area_15693.shp
# pad_area_15816.shp
# pad_area_15898.shp
# pad_area_16071.shp
# pad_area_16178.shp
# pad_area_1621.shp
# pad_area_16227.shp
# pad_area_1625.shp
# pad_area_16329.shp
# pad_area_16333.shp
# pad_area_16388.shp
# pad_area_16458.shp
# pad_area_16483.shp
# pad_area_1652.shp
# pad_area_16526.shp
# pad_area_16599.shp
# pad_area_16653.shp
# pad_area_1673.shp
# pad_area_168.shp
# pad_area_16816.shp
# pad_area_16901.shp
# pad_area_1704.shp
# pad_area_1712.shp
# pad_area_17161.shp
# pad_area_17175.shp
# pad_area_1727.shp
# pad_area_17517.shp
# pad_area_17553.shp
# pad_area_178.shp
# pad_area_17955.shp
# pad_area_18071.shp
# pad_area_18153.shp
# pad_area_18200.shp
# pad_area_18247.shp
# pad_area_18272.shp
# pad_area_18304.shp
# pad_area_18337.shp
# pad_area_18375.shp
# pad_area_18397.shp
# pad_area_18447.shp
# pad_area_18575.shp
# pad_area_18682.shp
# pad_area_18782.shp
# pad_area_18890.shp
# pad_area_18899.shp
# pad_area_1903.shp
# pad_area_1941.shp
# pad_area_1963.shp
# pad_area_1972.shp
# pad_area_2051.shp
# pad_area_2320.shp
# pad_area_2345.shp
# pad_area_2433.shp
# pad_area_2589.shp
# pad_area_2720.shp
# pad_area_2893.shp
# pad_area_2923.shp
# pad_area_3015.shp
# pad_area_3058.shp
# pad_area_3250.shp
# pad_area_3272.shp
# pad_area_343.shp
# pad_area_3444.shp
# pad_area_3445.shp
# pad_area_3472.shp
# pad_area_3599.shp
# pad_area_3601.shp
# pad_area_3610.shp
# pad_area_3634.shp
# pad_area_3638.shp
# pad_area_3645.shp
# pad_area_3659.shp
# pad_area_3922.shp
# pad_area_3924.shp
# pad_area_4009.shp
# pad_area_4735.shp
# pad_area_4773.shp
# pad_area_4807.shp
# pad_area_4846.shp
# pad_area_5042.shp
# pad_area_5057.shp
# pad_area_5085.shp
# pad_area_5093.shp
# pad_area_5596.shp
# pad_area_5717.shp
# pad_area_5732.shp
# pad_area_5784.shp
# pad_area_5897.shp
# pad_area_5969.shp
# pad_area_5986.shp
# pad_area_5999.shp
# pad_area_6305.shp
# pad_area_6369.shp
# pad_area_6423.shp
# pad_area_6477.shp
# pad_area_6485.shp
# pad_area_6504.shp
# pad_area_6549.shp
# pad_area_6555.shp
# pad_area_6576.shp
# pad_area_6601.shp
# pad_area_6634.shp
# pad_area_6664.shp
# pad_area_6723.shp
# pad_area_6735.shp
# pad_area_6870.shp
# pad_area_6923.shp
# pad_area_7006.shp
# pad_area_7105.shp
# pad_area_7169.shp
# pad_area_7203.shp
# pad_area_7230.shp
# pad_area_7322.shp
# pad_area_7341.shp
# pad_area_7393.shp
# pad_area_7400.shp
# pad_area_7427.shp
# pad_area_7499.shp
# pad_area_7531.shp
# pad_area_7548.shp
# pad_area_7578.shp
# pad_area_7648.shp
# pad_area_7724.shp
# pad_area_7733.shp
# pad_area_7752.shp
# pad_area_7776.shp
# pad_area_7796.shp
# pad_area_7815.shp
# pad_area_7889.shp
# pad_area_7993.shp
# pad_area_8038.shp
# pad_area_8043.shp
# pad_area_8103.shp
# pad_area_8150.shp
# pad_area_8166.shp
# pad_area_8199.shp
# pad_area_8212.shp
# pad_area_8250.shp
# pad_area_8517.shp
# pad_area_8603.shp
# pad_area_863.shp
# pad_area_8658.shp
# pad_area_8667.shp
# pad_area_8791.shp
# pad_area_8834.shp
# pad_area_8870.shp
# pad_area_8960.shp
# pad_area_8992.shp
# pad_area_9010.shp
# pad_area_9011.shp
# pad_area_9044.shp
# pad_area_9070.shp
# pad_area_9080.shp
# pad_area_9081.shp
# pad_area_9082.shp
# pad_area_9093.shp
# pad_area_9115.shp
# pad_area_9172.shp
# pad_area_9178.shp
# pad_area_953.shp
# pad_area_9547.shp
# pad_area_9653.shp
# pad_area_9697.shp
# pad_area_9732.shp
# pad_area_9766.shp
# pad_area_9792.shp
# pad_area_9890.shp
# pad_area_9921.shp
# pad_area_9945.shp
# pad_area_9959.shp
# pad_area_9973.shp
# pad_area_10017.shp
# pad_area_10077.shp
# pad_area_10125.shp
# pad_area_1013.shp
# pad_area_102.shp
# pad_area_10457.shp
# pad_area_10493.shp
# pad_area_10592.shp
# pad_area_10738.shp
# pad_area_10830.shp
# pad_area_1090.shp
# pad_area_11020_1.shp
# pad_area_11020_2.shp
# pad_area_11024.shp
# pad_area_11148.shp
# pad_area_11473.shp
# pad_area_115.shp
# pad_area_11516.shp
# pad_area_11555.shp
# pad_area_11562_1.shp
# pad_area_11562_2.shp
# pad_area_11581.shp
# pad_area_11624.shp
# pad_area_11632.shp
# pad_area_11676.shp
# pad_area_11765.shp
# pad_area_11814.shp
# pad_area_11841.shp
# pad_area_11877.shp
# pad_area_11920.shp
# pad_area_11963.shp
# pad_area_11968.shp
# pad_area_11983.shp
# pad_area_12040.shp
# pad_area_12072.shp
# pad_area_12120.shp
# pad_area_12126.shp
# pad_area_12164.shp
# pad_area_12193.shp
# pad_area_12197.shp
# pad_area_12221.shp
# pad_area_12449.shp
# pad_area_12492.shp
# pad_area_12506.shp
# pad_area_12539.shp
# pad_area_12722.shp
# pad_area_12960.shp
# pad_area_13010.shp
# pad_area_13031.shp
# pad_area_13036.shp
# pad_area_13063.shp
# pad_area_1319.shp
# pad_area_13294.shp
# pad_area_13324.shp
# pad_area_13346.shp
# pad_area_13347.shp
# pad_area_13411_1.shp
# pad_area_13444.shp
# pad_area_13451.shp
# pad_area_13478.shp
# pad_area_13494.shp
# pad_area_13512.shp
# pad_area_13538.shp
# pad_area_13663.shp
# pad_area_13816.shp
# pad_area_13885.shp
# pad_area_13891.shp
# pad_area_1397.shp
# pad_area_1402_1.shp
# pad_area_1402_2.shp
# pad_area_14042.shp
# pad_area_14147.shp
# pad_area_1421.shp
# pad_area_14241.shp
# pad_area_14277.shp
# pad_area_14312.shp
# pad_area_14346.shp
# pad_area_14370.shp
# pad_area_14416.shp
# pad_area_14500.shp
# pad_area_14541.shp
# pad_area_14557.shp
# pad_area_14583.shp
# pad_area_1460.shp
# pad_area_14600.shp
# pad_area_14624_1.shp
# pad_area_14624_2.shp
# pad_area_14624_3.shp
# pad_area_14624_4.shp
# pad_area_14674.shp
# pad_area_14682.shp
# pad_area_14698.shp
# pad_area_149.shp
# pad_area_15054.shp
# pad_area_15277.shp
# pad_area_15346.shp
# pad_area_15355.shp
# pad_area_1538.shp
# pad_area_15414.shp
# pad_area_15419.shp
# pad_area_15457.shp
# pad_area_15496.shp
# pad_area_15536.shp
# pad_area_15573.shp
# pad_area_15601.shp
# pad_area_15663.shp
# pad_area_15682.shp
# pad_area_15721.shp
# pad_area_15744.shp
# pad_area_15769.shp
# pad_area_15841.shp
# pad_area_15864.shp
# pad_area_16092.shp
# pad_area_16142.shp
# pad_area_16185.shp
# pad_area_16222.shp
# pad_area_16263.shp
# pad_area_16280.shp
# pad_area_1638.shp
# pad_area_16445.shp
# pad_area_16523.shp
# pad_area_16548.shp
# pad_area_16659.shp
# pad_area_16703.shp
# pad_area_16761.shp
# pad_area_16818.shp
# pad_area_16866.shp
# pad_area_16953.shp
# pad_area_16998.shp
# pad_area_17233.shp
# pad_area_17248.shp
# pad_area_17302.shp
# pad_area_17427.shp
# pad_area_17541.shp
# pad_area_17592.shp
# pad_area_17596.shp
# pad_area_17622.shp
# pad_area_1773.shp
# pad_area_1786.shp
# pad_area_1800.shp
# pad_area_18027.shp
# pad_area_18223.shp
# pad_area_18505.shp
# pad_area_1858.shp
# pad_area_18747.shp
# pad_area_1978.shp
# pad_area_1992.shp
# pad_area_2056.shp
# pad_area_2067.shp
# pad_area_2107.shp
# pad_area_213.shp
# pad_area_2203.shp
# pad_area_2263.shp
# pad_area_2355.shp
# pad_area_2580.shp
# pad_area_2657.shp
# pad_area_2686.shp
# pad_area_2796.shp
# pad_area_2810.shp
# pad_area_2827.shp
# pad_area_2896.shp
# pad_area_2913_1.shp
# pad_area_2913_2.shp
# pad_area_2922.shp
# pad_area_306.shp
# pad_area_3090.shp
# pad_area_3458.shp
# pad_area_3531.shp
# pad_area_3690.shp
# pad_area_3703.shp
# pad_area_4467.shp
# pad_area_455.shp
# pad_area_4978.shp
# pad_area_5017.shp
# pad_area_5041.shp
# pad_area_5108.shp
# pad_area_5109.shp
# pad_area_5140.shp
# pad_area_5150.shp
# pad_area_520.shp
# pad_area_5209.shp
# pad_area_5213.shp
# pad_area_5237.shp
# pad_area_5277.shp
# pad_area_5296.shp
# pad_area_56.shp
# pad_area_5771.shp
# pad_area_6102.shp
# pad_area_646.shp
# pad_area_648.shp
# pad_area_65.shp
# pad_area_658.shp
# pad_area_66.shp
# pad_area_6813.shp
# pad_area_6881.shp
# pad_area_6948.shp
# pad_area_7064.shp
# pad_area_7116.shp
# pad_area_7513.shp
# pad_area_759.shp
# pad_area_7601.shp
# pad_area_7653.shp
# pad_area_7763.shp
# pad_area_7875.shp
# pad_area_8069.shp
# pad_area_8074.shp
# pad_area_8303.shp
# pad_area_8318.shp
# pad_area_85.shp
# pad_area_8522.shp
# pad_area_862.shp
# pad_area_8661.shp
# pad_area_8671.shp
# pad_area_8681.shp
# pad_area_8735.shp
# pad_area_8876.shp
# pad_area_8966.shp
# pad_area_9078.shp
# pad_area_9088.shp
# pad_area_9089.shp
# pad_area_9095.shp
# pad_area_91.shp
# pad_area_9105.shp
# pad_area_9116.shp
# pad_area_9117.shp
# pad_area_9169.shp
# pad_area_9211_1.shp
# pad_area_9211_2.shp
# pad_area_9238.shp
# pad_area_9263.shp
# pad_area_96.shp
# pad_area_9604.shp
# pad_area_9618.shp
# pad_area_9816.shp
# pad_area_9847.shp
# pad_area_9875.shp
# pad_area_995.shp
# pad_area_10171.shp
# pad_area_10198.shp
# pad_area_10203.shp
# pad_area_10228.shp
# pad_area_10247.shp
# pad_area_10277.shp
# pad_area_10324.shp
# pad_area_10413.shp
# pad_area_10531.shp
# pad_area_10557.shp
# pad_area_10636.shp
# pad_area_10786.shp
# pad_area_10979.shp
# pad_area_11234.shp
# pad_area_11238.shp
# pad_area_11432.shp
# pad_area_13105.shp
# pad_area_13119.shp
# pad_area_13153.shp
# pad_area_13198.shp
# pad_area_13624.shp
# pad_area_16287.shp
# pad_area_16371.shp
# pad_area_16417.shp
# pad_area_16583.shp
# pad_area_16738.shp
# pad_area_17210.shp
# pad_area_17328.shp
# pad_area_17363.shp
# pad_area_17374.shp
# pad_area_17388.shp
# pad_area_17920.shp
# pad_area_18569.shp
# pad_area_18605.shp
# pad_area_18618.shp
# pad_area_18818.shp
# pad_area_2080.shp
# pad_area_2094.shp
# pad_area_2561.shp
# pad_area_2604.shp
# pad_area_2739.shp
# pad_area_2929.shp
# pad_area_3023.shp
# pad_area_3205.shp
# pad_area_3421.shp
# pad_area_3454.shp
# pad_area_3461.shp
# pad_area_347.shp
# pad_area_3477.shp
# pad_area_349.shp
# pad_area_3501.shp
# pad_area_3535.shp
# pad_area_3565.shp
# pad_area_3624.shp
# pad_area_3876.shp
# pad_area_3886.shp
# pad_area_3921.shp
# pad_area_3928.shp
# pad_area_3932.shp
# pad_area_4030.shp
# pad_area_4052.shp
# pad_area_4482.shp
# pad_area_4582.shp
# pad_area_4631.shp
# pad_area_4850.shp
# pad_area_4851.shp
# pad_area_4886.shp
# pad_area_4892.shp
# pad_area_4917.shp
# pad_area_4949.shp
# pad_area_4976.shp
# pad_area_5039.shp
# pad_area_5053.shp
# pad_area_5062.shp
# pad_area_5087.shp
# pad_area_5116_1.shp
# pad_area_5116_2.shp
# pad_area_5123.shp
# pad_area_5264.shp
# pad_area_5560.shp
# pad_area_5719.shp
# pad_area_5919.shp
# pad_area_6182.shp
# pad_area_6193.shp
# pad_area_6198.shp
# pad_area_6217.shp
# pad_area_6226.shp
# pad_area_6233.shp
# pad_area_6339.shp
# pad_area_6377.shp
# pad_area_6402.shp
# pad_area_6445_1.shp
# pad_area_6445_2.shp
# pad_area_6448.shp
# pad_area_6741.shp
# pad_area_7032.shp
# pad_area_7084.shp
# pad_area_7117.shp
# pad_area_7156.shp
# pad_area_7192.shp
# pad_area_7196.shp
# pad_area_7249.shp
# pad_area_7255.shp
# pad_area_7366.shp
# pad_area_7453.shp
# pad_area_7564.shp
# pad_area_7693.shp
# pad_area_7704.shp
# pad_area_7853.shp
# pad_area_7906.shp
# pad_area_8000.shp
# pad_area_8999.shp
# pad_area_9200.shp
# pad_area_9228.shp
# pad_area_933.shp
# pad_area_10083.shp
# pad_area_10273.shp
# pad_area_11076.shp
# pad_area_11084.shp
# pad_area_11092.shp
# pad_area_11155.shp
# pad_area_11193.shp
# pad_area_11368.shp
# pad_area_11689.shp
# pad_area_11691.shp
# pad_area_11721.shp
# pad_area_11932.shp
# pad_area_11956.shp
# pad_area_12014.shp
# pad_area_12017.shp
# pad_area_12026.shp
# pad_area_12104.shp
# pad_area_12185.shp
# pad_area_12746.shp
# pad_area_12770.shp
# pad_area_12793.shp
# pad_area_12810.shp
# pad_area_12847.shp
# pad_area_12889.shp
# pad_area_12903.shp
# pad_area_12926.shp
# pad_area_12939.shp
# pad_area_12988.shp
# pad_area_13803.shp
# pad_area_14172.shp
# pad_area_14309.shp
# pad_area_14542.shp
# pad_area_14668.shp
# pad_area_15074.shp
# pad_area_15078.shp
# pad_area_15107.shp
# pad_area_15137.shp
# pad_area_15171.shp
# pad_area_15183.shp
# pad_area_15204.shp
# pad_area_15225.shp
# pad_area_15253.shp
# pad_area_15312.shp
# pad_area_15381.shp
# pad_area_15388.shp
# pad_area_16048.shp
# pad_area_18120.shp
# pad_area_18641.shp
# pad_area_18667.shp
# pad_area_18809.shp
# pad_area_18856.shp
# pad_area_1975.shp
# pad_area_2340.shp
# pad_area_4914.shp
# pad_area_4953.shp
# pad_area_4982.shp
# pad_area_4999.shp
# pad_area_5031.shp
# pad_area_5935.shp
# pad_area_6013.shp
# pad_area_6018.shp
# pad_area_6056.shp
# pad_area_6236.shp
# pad_area_629.shp
# pad_area_6708.shp
# pad_area_6826.shp
# pad_area_6843.shp
# pad_area_6845.shp
# pad_area_6966.shp
# pad_area_7202.shp
# pad_area_7210.shp
# pad_area_7890.shp
# pad_area_7900.shp
# pad_area_8072.shp
# pad_area_8242.shp
# pad_area_8263.shp
# pad_area_8283.shp
# pad_area_8331.shp
# pad_area_8629.shp
# pad_area_8662.shp
# pad_area_8727.shp
# pad_area_9321.shp
# pad_area_9376.shp
# pad_area_9436.shp
# pad_area_9473.shp
# pad_area_9476.shp
# pad_area_9501.shp
# pad_area_9508.shp
# pad_area_9553.shp
# pad_area_1974.shp
# pad_area_2155.shp
# pad_area_2618.shp
# pad_area_3560.shp
# pad_area_4685.shp
# pad_area_5006.shp
# pad_area_5026.shp
# pad_area_5711.shp
# pad_area_6108.shp
# pad_area_6229.shp
# pad_area_6752.shp
# pad_area_8460.shp
# pad_area_8538.shp
# pad_area_8732.shp
# pad_area_9068.shp
# pad_area_10792.shp
# pad_area_10953.shp
# pad_area_16118.shp
# pad_area_17140.shp
# pad_area_17434.shp
# pad_area_17481.shp
# pad_area_17683.shp
# pad_area_17753.shp
# pad_area_17883.shp
# pad_area_18710.shp
# pad_area_18725.shp
# pad_area_2883.shp
# pad_area_2979.shp
# pad_area_2986.shp
# pad_area_3126.shp
# pad_area_3159.shp
# pad_area_3194.shp
# pad_area_3202.shp
# pad_area_4299.shp
# pad_area_4418.shp
# pad_area_5605.shp
# pad_area_5636.shp
# pad_area_6252.shp
# pad_area_6765.shp
# pad_area_6779.shp
# pad_area_6794.shp
# pad_area_8456.shp
# pad_area_8555.shp
# pad_area_8904.shp

# %% [markdown]
# ## 生成annotation

# %%
#Read the training area 、 training polygons
trainingArea = gps.read_file(r'D:\lakemapping\2_dataset\sampleAnnotations\SampleV4\train_area.shp')
trainingPolygon = gps.read_file(r'D:\lakemapping\2_dataset\sampleAnnotations\SampleV4\train_polygon.shp')

print(trainingPolygon.shape,trainingArea.shape)# area:id, geomerry;   polygon:id, geometry 
trainingPolygon
trainingArea
# print(f'Read a total of {trainingPolygon.shape[0]} object polygons and {trainingArea.shape[0]} training areas.')
# print(f'Polygons will be assigned to training areas in the next steps.')
# Out:
# (131449, 3) (445, 6)
#            CLASS_NAME      area  \
# 0                Lake  0.018956
# 1       LakeLikeRiver  0.040392
# 2       LakeLikeRiver  0.230842
# 3                Lake  0.029674
# 4                Lake  0.005558
# ...               ...       ...
# 131444      Reservoir  0.189746
# 131445      Reservoir  0.000091
# 131446      Reservoir  0.915970
# 131447           Lake  0.225691
# 131448  LakeLikeRiver  0.082832
#
#                                                  geometry
# 0       POLYGON Z ((-66.54333 -2.42330 0.00000, -66.54...
# 1       POLYGON Z ((-66.49653 -2.42321 0.00000, -66.49...
# 2       POLYGON Z ((-66.49959 -2.42312 0.00000, -66.49...
# 3       POLYGON Z ((-66.43051 -2.42132 0.00000, -66.43...
# 4       POLYGON Z ((-66.55762 -2.43021 0.00000, -66.55...
# ...                                                   ...
# 131444  POLYGON Z ((33.00752 24.34722 0.00000, 33.0074...
# 131445  POLYGON Z ((33.02126 24.33500 0.00000, 33.0212...
# 131446  POLYGON Z ((33.02135 24.33509 0.00000, 33.0213...
# 131447  POLYGON Z ((174.36704 64.65400 0.00000, 174.36...
# 131448  POLYGON Z ((174.38186 64.66370 0.00000, 174.38...
#
# [131449 rows x 3 columns]
#         id  type file_name dataset        area  \
# 0     2913     1    2913_1   train  122.289714
# 1       65     1        65   train  446.782976
# 2       85     1        85   train  359.016936
# 3       96     1        96   train  567.541389
# 4      102     1       102   train  176.831955
# ..     ...   ...       ...     ...         ...
# 440  18682     0     18682   train  414.393331
# 441  18710     5     18710   train  375.745158
# 442  18818     2     18818   train  185.891121
# 443  18856     3     18856   train  192.827160
# 444  18890     0     18890   train  105.793754
#
#                                               geometry
# 0    POLYGON Z ((-3.69199 16.13554 0.00000, -3.5400...
# 1    POLYGON Z ((-76.80614 6.22074 0.00000, -76.646...
# 2    POLYGON Z ((-74.20875 6.79620 0.00000, -74.051...
# 3    POLYGON Z ((-74.00941 7.49429 0.00000, -73.840...
# 4    POLYGON Z ((-72.33154 3.79646 0.00000, -72.264...
# ..                                                 ...
# 440  POLYGON Z ((-70.93654 -48.43438 0.00000, -70.6...
# 441  POLYGON Z ((-68.81463 -40.45141 0.00000, -68.6...
# 442  POLYGON Z ((172.52783 -43.44513 0.00000, 172.6...
# 443  POLYGON Z ((-71.99683 -53.30585 0.00000, -71.8...
# 444  POLYGON Z ((-66.00668 -54.66042 0.00000, -65.8...
#
# [445 rows x 6 columns]

# %%
# Check if the training areas and the training polygons have the same crs     
if trainingArea.crs  != trainingPolygon.crs:
    print('Training area CRS does not match training_polygon CRS')
    targetCRS = trainingPolygon.crs #Areas are less in number so conversion should be faster
    trainingArea = trainingArea.to_crs(targetCRS)
print(trainingPolygon.crs)
print(trainingArea.crs)
assert trainingPolygon.crs == trainingArea.crs
# Out:
# epsg:4326
# epsg:4326

# %%
# As input we received two shapefile, first one contains the training areas/rectangles and other contains the polygon of lakes/objects in those training areas
# The first task is to determine the parent training area for each polygon.

def dividePolygonsInTrainingAreas(trainingPolygon, trainingArea):
    '''Assign annotated ploygons in to the training areas.'''
    # For efficiency, assigned polygons are removed from the list, we make a copy here. 
    cpTrainingPolygon = trainingPolygon.copy()
    splitPolygons = {}
    for i in tqdm(trainingArea.index):
        spTemp = [] 
        allocated = []
        print("area's index:",i)
        for j in cpTrainingPolygon.index:
            if cpTrainingPolygon.loc[j]['geometry'].intersects(trainingArea.loc[i]['geometry']):
                spTemp.append(cpTrainingPolygon.loc[j])
                allocated.append(j)      
        splitPolygons[i] = {'polygons':spTemp,'bounds':list(trainingArea.bounds.loc[i]),'file_name':trainingArea.loc[i]['file_name'] ,'type':trainingArea.loc[i]['type']}
        cpTrainingPolygon = cpTrainingPolygon.drop(allocated)#assigned polygons are removed from the list
    return splitPolygons

# areasWithPolygons contains the object polygons for each area!
areasWithPolygons = dividePolygonsInTrainingAreas(trainingPolygon, trainingArea)
print(f'Assigned training polygons in {len(areasWithPolygons)} training areas')
# Out:
#   0%|          | 0/445 [00:00<?, ?it/s]
# area's index: 0
# area's index: 1
# area's index: 2
# area's index: 3
# area's index: 4
# area's index: 5
# area's index: 6
# area's index: 7
# area's index: 8
# area's index: 9
# area's index: 10
# area's index: 11
# area's index: 12
# area's index: 13
# area's index: 14
# area's index: 15
# area's index: 16
# area's index: 17
# area's index: 18
# area's index: 19
# area's index: 20
# area's index: 21
# area's index: 22
# area's index: 23
# area's index: 412
# area's index: 413
# area's index: 414
# area's index: 415
# area's index: 416
# area's index: 417
# area's index: 418
# area's index: 419
# area's index: 420
# area's index: 421
# area's index: 422
# area's index: 423
# area's index: 424
# area's index: 425
# area's index: 426
# area's index: 427
# area's index: 428
# area's index: 429
# area's index: 430
# area's index: 431
# area's index: 432
# area's index: 433
# area's index: 434
# area's index: 435
# area's index: 436
# area's index: 437
# area's index: 438
# area's index: 439
# area's index: 440
# area's index: 441
# area's index: 442
# area's index: 443
# area's index: 444
# Assigned training polygons in 445 training areas

# %%
# print(areasWithPolygons)

# %%
def extractAreasThatOverlapWithTrainingData(areaInfo):
    """Iterates over raw NDWI images and using findOverlap() extract areas that overlap with training data. 
    The overlapping areas in raw images are written in a separate file, and annotation file are created from polygons in the overlapping areas.
    """   
    polygonsInAreaDf = gps.GeoDataFrame(areaInfo['polygons'])
    file_name=str(areaInfo['file_name'])
    bboxArea = box(*areaInfo['bounds'])
    area_type=areaInfo['type']
    writePath=os.path.join(output_dir,'image\output{}'.format(area_type))
    if not os.path.exists(writePath):
        os.makedirs(writePath)
    #draw image: set pad width of the sample images
    raw_img = rasterio.open(os.path.join(writePath,image_prefix+file_name+image_file_type))
    profile = raw_img.profile  
    profile['dtype'] = rasterio.uint8
#     profile['nodata']= None
    profile['count'] = 1
    polygons = []
    for i in polygonsInAreaDf.index:
        gm = polygonsInAreaDf.loc[i]['geometry']
        polygons.append(gm)
    output_filename=os.path.join(writePath,annotation_prefix+file_name+annotation_file_type)
    if not os.path.exists(output_filename):
        print(output_filename)
        with rasterio.open(output_filename, 'w+', **profile) as out:
            out_arr = out.read(1)
            burned = features.rasterize(polygons, fill=0, default_value=1,all_touched=False,out=out_arr, transform=out.transform)
            out.write_band(1, burned)

# %%
for value in areasWithPolygons.values():
    extractAreasThatOverlapWithTrainingData(value)
# Out:
# D:\sample\image\output1\annotation_2913_1.png
# D:\sample\image\output1\annotation_65.png
# D:\sample\image\output1\annotation_85.png
# D:\sample\image\output1\annotation_96.png
# D:\sample\image\output1\annotation_102.png
# D:\sample\image\output1\annotation_115.png
# D:\sample\image\output1\annotation_149.png
# D:\sample\image\output0\annotation_168.png
# D:\sample\image\output0\annotation_178.png
# D:\sample\image\output1\annotation_213.png
# D:\sample\image\output1\annotation_306.png
# D:\sample\image\output0\annotation_343.png
# D:\sample\image\output1\annotation_520.png
# D:\sample\image\output1\annotation_646.png
# D:\sample\image\output1\annotation_648.png
# D:\sample\image\output1\annotation_862.png
# D:\sample\image\output0\annotation_863.png
# D:\sample\image\output2\annotation_933.png
# D:\sample\image\output0\annotation_953.png
# D:\sample\image\output1\annotation_1090.png
# D:\sample\image\output0\annotation_1260.png
# D:\sample\image\output1\annotation_1397.png
# D:\sample\image\output1\annotation_1402_2.png
# D:\sample\image\output1\annotation_1460.png
# D:\sample\image\output1\annotation_1538.png
# D:\sample\image\output0\annotation_1543_1.png
# D:\sample\image\output0\annotation_1621.png
# D:\sample\image\output0\annotation_1727.png
# D:\sample\image\output1\annotation_1858.png
# D:\sample\image\output1\annotation_16263.png
# D:\sample\image\output0\annotation_16329.png
# D:\sample\image\output0\annotation_16333.png
# D:\sample\image\output2\annotation_16371.png
# D:\sample\image\output0\annotation_16388.png
# D:\sample\image\output2\annotation_16417.png
# D:\sample\image\output1\annotation_16445.png
# D:\sample\image\output0\annotation_16458.png
# D:\sample\image\output0\annotation_16483.png
# D:\sample\image\output1\annotation_16523.png
# D:\sample\image\output0\annotation_16526.png
# D:\sample\image\output1\annotation_16548.png
# D:\sample\image\output2\annotation_16583.png
# D:\sample\image\output0\annotation_16653.png
# D:\sample\image\output1\annotation_16703.png
# D:\sample\image\output1\annotation_16761.png
# D:\sample\image\output1\annotation_16818.png
# D:\sample\image\output0\annotation_16901.png
# D:\sample\image\output1\annotation_16998.png
# D:\sample\image\output5\annotation_17140.png
# D:\sample\image\output0\annotation_17175.png
# D:\sample\image\output2\annotation_17210.png
# D:\sample\image\output1\annotation_17233.png
# D:\sample\image\output1\annotation_17248.png
# D:\sample\image\output1\annotation_17302.png
# D:\sample\image\output2\annotation_17328.png
# D:\sample\image\output2\annotation_17363.png
# D:\sample\image\output1\annotation_17427.png
# D:\sample\image\output5\annotation_17434.png
# D:\sample\image\output5\annotation_17481.png
# D:\sample\image\output0\annotation_17517.png
# D:\sample\image\output1\annotation_17622.png
# D:\sample\image\output2\annotation_17920.png
# D:\sample\image\output0\annotation_18153.png
# D:\sample\image\output0\annotation_18200.png
# D:\sample\image\output0\annotation_18272.png
# D:\sample\image\output0\annotation_18397.png
# D:\sample\image\output0\annotation_18447.png
# D:\sample\image\output1\annotation_18505.png
# D:\sample\image\output0\annotation_18575.png
# D:\sample\image\output2\annotation_18605.png
# D:\sample\image\output3\annotation_18667.png
# D:\sample\image\output0\annotation_18682.png
# D:\sample\image\output5\annotation_18710.png
# D:\sample\image\output2\annotation_18818.png
# D:\sample\image\output3\annotation_18856.png
# D:\sample\image\output0\annotation_18890.png

# %% [markdown]
# ## 划分数据集

# %%
def moveFileinType(lakeType,patchType,fn):
    output_dir=os.path.join(dataset_dir,r'patchesReshape/{}/type{}'.format(patchType,lakeType))
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    move(output_dir,fn)
    move(output_dir,fn.replace(image_prefix,annotation_prefix).replace(image_file_type,annotation_file_type))
    move(output_dir,fn.replace(image_prefix,pad_image_prefix))
    
def move(output_dir,fn):
    old=os.path.join(patch_output,fn)
    if(os.path.exists(old)):
        new=os.path.join(output_dir,fn)
        shutil.move(old, new)

# %%
# split dataset and copy images & annotations to new directory
for i in range(0,type_num):
    frames = []
    frames_json = os.path.join(patch_dir,'sample_list_supplement_{}.json'.format(i))
#     print(frames_json)
    patch_output = os.path.join(dataset_dir,r'output\output{}'.format(i))
    all_files = os.listdir(patch_output)
    all_image_files = [fn for fn in all_files if fn.startswith(image_prefix) and fn.endswith(image_file_type)]
    len(all_image_files)
    print(all_image_files)

    if os.path.isfile(frames_json):
        print("dataset type{} had been splited".format(i))
#             train data are classified into different dirs for following process.
        with open(frames_json, 'r') as file:
            fjson = json.load(file)#
            for train_fn in fjson['training_frames']:
                moveFileinType(i,'train',train_fn)
            for testing_fn in fjson['testing_frames']:
                moveFileinType(i,'test',testing_fn)
            for validation_fn in fjson['validation_frames']:
                moveFileinType(i,'val',validation_fn)
    else:
            print("Creating and writing train-test split from file")
            frames_list = list(range(len(all_image_files)))
            
            # Divide into training and test set       
            training_frames, testing_frames = train_test_split(frames_list, test_size=test_ratio)
            # Further divide into training set into training and validataion set              
            training_frames, validation_frames = train_test_split(training_frames, test_size=val_ratio)
            
            training_frames_name=[all_image_files[id] for id in training_frames]
            testing_frames_name=[all_image_files[id] for id in testing_frames]
            validation_frames_name=[all_image_files[id] for id in validation_frames]
            
            # train data are classified into different dirs for following process.
            for train_fn in training_frames_name:
                moveFileinType(i,'train',train_fn)
            for testing_fn in testing_frames_name:
                moveFileinType(i,'test',testing_fn) 
            for validation_fn in validation_frames_name:
                moveFileinType(i,'val',validation_fn)
                
            frame_split = {
                'training_frames': training_frames_name,
                'testing_frames': testing_frames_name,
                'validation_frames': validation_frames_name
            }
            
            if not os.path.exists(patch_dir):
                os.makedirs(patch_dir)
            with open(frames_json, 'w') as f:
                json.dump(frame_split, f)
                
            print('training_frames', training_frames_name)
            print('validation_frames',validation_frames_name )
            print('testing_frames', testing_frames_name)
# Out:
# 80
# ['image_13177.tif', 'image_13224.tif', 'image_13246.tif', 'image_13251.tif', 'image_13307.tif', 'image_13362.tif', 'image_13407.tif', 'image_13554.tif', 'image_13582.tif', 'image_13618.tif', 'image_13705.tif', 'image_13742.tif', 'image_13748.tif', 'image_13830.tif', 'image_13928.tif', 'image_13944.tif', 'image_13962.tif', 'image_13979.tif', 'image_14006.tif', 'image_14077.tif', 'image_14084.tif', 'image_14111.tif', 'image_14206.tif', 'image_14422.tif', 'image_14449.tif', 'image_14494.tif', 'image_14689.tif', 'image_14735.tif', 'image_14753.tif', 'image_14781.tif', 'image_14807.tif', 'image_14836.tif', 'image_14857.tif', 'image_14862.tif', 'image_14872.tif', 'image_14914.tif', 'image_14926.tif', 'image_14947.tif', 'image_14975.tif', 'image_14997.tif', 'image_15009.tif', 'image_15612.tif', 'image_15693.tif', 'image_15816.tif', 'image_15898.tif', 'image_16071.tif', 'image_16178.tif', 'image_16227.tif', 'image_16329.tif', 'image_16333.tif', 'image_16388.tif', 'image_16458.tif', 'image_16483.tif', 'image_16526.tif', 'image_16599.tif', 'image_16653.tif', 'image_16816.tif', 'image_16901.tif', 'image_17161.tif', 'image_17175.tif', 'image_17517.tif', 'image_17553.tif', 'image_17955.tif', 'image_18071.tif', 'image_18153.tif', 'image_18200.tif', 'image_18247.tif', 'image_18272.tif', 'image_18304.tif', 'image_18337.tif', 'image_18375.tif', 'image_18397.tif', 'image_18447.tif', 'image_18575.tif', 'image_18682.tif', 'image_18782.tif', 'image_18890.tif', 'image_18899.tif', 'image_2345.tif', 'image_953.tif']
# dataset type0 had been splited
# 91
